# %%
import psycopg2 as pg

# %%
with pg.connect(database='pandas_db',user='postgres',password=1533,host='localhost',port=5432) as conn:
    with conn.cursor() as cur:
        cur.execute('SELECT * FROM USERS')
        for i in cur.fetechall():
            print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 4
#       2 with conn.cursor() as cur:
#       3     cur.execute('SELECT * FROM USERS')
# ----> 4     for i in cur.fetechall():
#       5         print(i)
#
# AttributeError: 'psycopg2.extensions.cursor' object has no attribute 'fetechall'
