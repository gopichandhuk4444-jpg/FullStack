# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates=pd.date_range('20031205',periods=6)
dates
# Out:
# DatetimeIndex(['2003-12-05', '2003-12-06', '2003-12-07', '2003-12-08',
#                '2003-12-09', '2003-12-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df=pd.DataFrame(np.random.randint(1,100,(6,4)),index=dates,columns=list('ABCD'))
df
# Out:
#              A   B   C   D
# 2003-12-05  30  98  64  75
# 2003-12-06  18  34  95  44
# 2003-12-07  60  22  10  20
# 2003-12-08  21  20  12  38
# 2003-12-09  20  61  34  72
# 2003-12-10  23   8  75  92

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.date_range("20130102",periods=4),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    })
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-03  1.0  3  train  foo
# 2  1.0 2013-01-04  1.0  3   test  foo
# 3  1.0 2013-01-05  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.head()
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-03  1.0  3  train  foo
# 2  1.0 2013-01-04  1.0  3   test  foo
# 3  1.0 2013-01-05  1.0  3  train  foo

# %%
df.tail(3)
# Out:
#              A   B   C   D
# 2003-12-08  21  20  12  38
# 2003-12-09  20  61  34  72
# 2003-12-10  23   8  75  92

# %%
df.index
# Out:
# DatetimeIndex(['2003-12-05', '2003-12-06', '2003-12-07', '2003-12-08',
#                '2003-12-09', '2003-12-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-03 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-04 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-05 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#                A          B          C          D
# count   6.000000   6.000000   6.000000   6.000000
# mean   28.666667  40.500000  48.333333  56.833333
# std    15.895492  33.429029  35.012379  27.102890
# min    18.000000   8.000000  10.000000  20.000000
# 25%    20.250000  20.500000  17.500000  39.500000
# 50%    22.000000  28.000000  49.000000  58.000000
# 75%    28.250000  54.250000  72.250000  74.250000
# max    60.000000  98.000000  95.000000  92.000000

# %%
df.T
# Out:
#    2003-12-05  2003-12-06  2003-12-07  2003-12-08  2003-12-09  2003-12-10
# A          30          18          60          21          20          23
# B          98          34          22          20          61           8
# C          64          95          10          12          34          75
# D          75          44          20          38          72          92

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#              A   B   C   D
# 2003-12-10  23   8  75  92
# 2003-12-09  20  61  34  72
# 2003-12-08  21  20  12  38
# 2003-12-07  60  22  10  20
# 2003-12-06  18  34  95  44
# 2003-12-05  30  98  64  75

# %%
df.sort_values(by='A')
# Out:
#              A   B   C   D
# 2003-12-06  18  34  95  44
# 2003-12-09  20  61  34  72
# 2003-12-08  21  20  12  38
# 2003-12-10  23   8  75  92
# 2003-12-05  30  98  64  75
# 2003-12-07  60  22  10  20

# %%
df['A']
# Out:
# 2003-12-05    30
# 2003-12-06    18
# 2003-12-07    60
# 2003-12-08    21
# 2003-12-09    20
# 2003-12-10    23
# Freq: D, Name: A, dtype: int32

# %%
df[4:]
# Out:
#              A   B   C   D
# 2003-12-09  20  61  34  72
# 2003-12-10  23   8  75  92

# %%
df.loc['20031205':'20031209',['A','C']]
# Out:
#              A   C
# 2003-12-05  30  64
# 2003-12-06  18  95
# 2003-12-07  60  10
# 2003-12-08  21  12
# 2003-12-09  20  34

# %%
df.iloc[:,:]
# Out:
#              A   B   C   D
# 2003-12-05  30  98  64  75
# 2003-12-06  18  34  95  44
# 2003-12-07  60  22  10  20
# 2003-12-08  21  20  12  38
# 2003-12-09  20  61  34  72
# 2003-12-10  23   8  75  92

# %%
df.iloc[0:3,:2]
# Out:
#              A   B
# 2003-12-05  30  98
# 2003-12-06  18  34
# 2003-12-07  60  22

# %%
df[df['A']>15]
# Out:
#              A   B   C   D
# 2003-12-05  30  98  64  75
# 2003-12-06  18  34  95  44
# 2003-12-07  60  22  10  20
# 2003-12-08  21  20  12  38
# 2003-12-09  20  61  34  72
# 2003-12-10  23   8  75  92

# %%
df[df>20]
# Out:
#                A     B     C     D
# 2003-12-05  30.0  98.0  64.0  75.0
# 2003-12-06   NaN  34.0  95.0  44.0
# 2003-12-07  60.0  22.0   NaN   NaN
# 2003-12-08  21.0   NaN   NaN  38.0
# 2003-12-09   NaN  61.0  34.0  72.0
# 2003-12-10  23.0   NaN  75.0  92.0

# %%
df[df['B'].isin([34,56])]
# Out:
#              A   B   C   D
# 2003-12-06  18  34  95  44

# %%
s1=pd.Series([4,1,3,5,7],index=pd.date_range('20250909',periods=5))
s1
# Out:
# 2025-09-09    4
# 2025-09-10    1
# 2025-09-11    3
# 2025-09-12    5
# 2025-09-13    7
# Freq: D, dtype: int64

# %%
df.at[dates[0],'A']=44
df
# Out:
#              A   B   C   D
# 2003-12-05  44  98  64  75
# 2003-12-06  18  34  95  44
# 2003-12-07  60  22  10  20
# 2003-12-08  21  20  12  38
# 2003-12-09  20  61  34  72
# 2003-12-10  23   8  75  92

# %%
df.iat[5,1]=48
df
# Out:
#              A   B   C   D
# 2003-12-05  44  98  64  75
# 2003-12-06  18  34  95  44
# 2003-12-07  60  22  10  20
# 2003-12-08  21  20  12  38
# 2003-12-09  20  61  34  72
# 2003-12-10  23  48  75  92

# %%
df['A'].value_counts()
# Out:
# A
# 44    1
# 18    1
# 60    1
# 21    1
# 20    1
# 23    1
# Name: count, dtype: int64

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)
df
# Out:
#      A      B         C         D
# 0  foo    one  0.889442 -1.098511
# 1  bar    one -1.322773  0.490052
# 2  foo    two  0.222747  0.860358
# 3  bar  three  0.859905 -0.765984
# 4  foo    two -1.400888  0.030683
# 5  bar    two -0.902853 -2.301098
# 6  foo    one -1.136821 -1.456440
# 7  foo  three  0.185417 -0.879810

# %%
df.groupby(['A','B'])['D'].sum()
# Out:
# A    B
# bar  one      0.490052
#      three   -0.765984
#      two     -2.301098
# foo  one     -2.554951
#      three   -0.879810
#      two      0.891041
# Name: D, dtype: float64

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  1.021761  0.880833
# 1     one  B  foo  1.906696 -0.539238
# 2     two  C  foo -1.979573  1.468377
# 3   three  A  bar  0.330168 -0.528570
# 4     one  B  bar -1.525660 -0.663397
# 5     one  C  bar -0.620414  0.818872
# 6     two  A  foo  0.703943  0.945298
# 7   three  B  foo -1.707438 -1.057070
# 8     one  C  foo  2.955938  1.886566
# 9     one  A  bar -1.235075 -0.772207
# 10    two  B  bar  0.408224  0.105954
# 11  three  C  bar -0.472043  1.316536

# %%
pd.pivot_table(df,index=['A','B'],columns='C',values=['D','E'])
# Out:
#                 D                   E
# C             bar       foo       bar       foo
# A     B
# one   A -1.235075  1.021761 -0.772207  0.880833
#       B -1.525660  1.906696 -0.663397 -0.539238
#       C -0.620414  2.955938  0.818872  1.886566
# three A  0.330168       NaN -0.528570       NaN
#       B       NaN -1.707438       NaN -1.057070
#       C -0.472043       NaN  1.316536       NaN
# two   A       NaN  0.703943       NaN  0.945298
#       B  0.408224       NaN  0.105954       NaN
#       C       NaN -1.979573       NaN  1.468377

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts.resample("5Min").sum()
# Out:
# 2012-01-01    23514
# Freq: 5min, dtype: int32

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df["grade"] = df["raw_grade"].astype("category")
df.dtypes
# Out:
# id              int64
# raw_grade      object
# grade        category
# dtype: object

# %%
new_categories = ["very good", "good", "very bad"]

df["grade"] = df["grade"].cat.rename_categories(new_categories)
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
# %pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.10.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# attrs                     25.3.0
# babel                     2.17.0
# beautifulsoup4            4.13.5
# bleach                    6.2.0
# certifi                   2025.8.3
# cffi                      1.17.1
# charset-normalizer        3.4.3
# colorama                  0.4.6
# comm                      0.2.3
# contourpy                 1.3.3
# cycler                    0.12.1
# debugpy                   1.8.16
# decorator                 5.2.1
# defusedxml                0.7.1
# et_xmlfile                2.0.0
# executing                 2.2.0
# fastjsonschema            2.21.2
# fonttools                 4.59.2
# fqdn                      1.5.1
# greenlet                  3.2.4
# ...

# %%
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(
    np.random.randn(100, 4), index=ts.index, columns=["A", "B", "C", "D"]
)
df=df.cumsum()
plt.figure()
df.plot()
plt.legend(loc='best')

# %%
# Example data
df = pd.DataFrame({
    "DOB": ["20121204", "20020101", "20010503", "20030102", "20020402"]
})

# Convert to datetime
df["DOB"] = pd.to_datetime(df["DOB"],format='%Y%m%d', errors="coerce", dayfirst=True)
df
# Out:
#          DOB
# 0 2012-12-04
# 1 2002-01-01
# 2 2001-05-03
# 3 2003-01-02
# 4 2002-04-02
