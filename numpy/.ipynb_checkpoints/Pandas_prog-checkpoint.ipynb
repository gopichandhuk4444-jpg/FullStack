# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([10,2,3,4])
s
# Out:
# 0    10
# 1     2
# 2     3
# 3     4
# dtype: int64

# %%
s.dtype
# Out:
# dtype('float64')

# %%
s.values
# Out:
# array([10.2,  3. ,  4. ])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s.name = 'Calories'

# %%
s
# Out:
# 0    10.2
# 1     3.0
# 2     4.0
# Name: Numbers, dtype: float64

# %%
s[0]
# Out:
# np.float64(10.2)

# %%
s[0:2] # ending is not included
# Out:
# 0    10.2
# 1     3.0
# Name: Numbers, dtype: float64

# %%
s.iloc[2]
# Out:
# np.float64(4.0)

# %%
s.iloc[[1,2]]
# Out:
# 1    3.0
# 2    4.0
# Name: Numbers, dtype: float64

# %%
index = ['apple', 'mango', 'orange', 'grapes']

# %%
s.index=index
s
# Out:
# apple     10
# mango      2
# orange     3
# grapes     4
# Name: Calories, dtype: int64

# %%
s['grapes']
# Out:
# np.int64(4)

# %%
s.loc['mango':'grapes'] # ending is included
# Out:
# mango     2
# orange    3
# grapes    4
# Name: Calories, dtype: int64

# %%
s.loc[['grapes','apple']]
# Out:
# grapes     4
# apple     10
# Name: Calories, dtype: int64

# %%
fruits_protein = {
    'avakado':2.0,
    'guava':2.6,
    'blackberies':2.0,
    'oranges':0.9,
    'banana':1.1,
    'apple':1.3,
    'kivi':1.1,
    'pomogranate':1.7,
    'mango':.8,
    'cheries':1
}

# %%
s2 = pd.Series(fruits_protein,name='protein')
s2
# Out:
# avakado        2.0
# guava          2.6
# blackberies    2.0
# oranges        0.9
# banana         1.1
# apple          1.3
# kivi           1.1
# pomogranate    1.7
# mango          0.8
# cheries        1.0
# Name: protein, dtype: float64

# %%
s2[(s2>1) & (s2<=2)]
# Out:
# avakado        2.0
# blackberies    2.0
# banana         1.1
# apple          1.3
# kivi           1.1
# pomogranate    1.7
# Name: protein, dtype: float64

# %%
data ={
    'name':['ajay','ram','sam','gopi','vinay'],
    'age':[20,25,np.nan,24,30],
    'department':['HR','IT','Finance','IT','HR'],
    'salary':[65000,50000,90000,99000,np.nan]
}

# %%
data
# Out:
# {'name': ['ajay', 'ram', 'sam', 'gopi', 'vinay'],
#  'age': [20, 25, 23, 24, 30],
#  'department': ['HR', 'IT', 'Finance', 'IT', 'HR'],
#  'salary': [65000, 50000, 90000, 99000, 40000]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     name   age department   salary
# 0   ajay  20.0         HR  65000.0
# 1    ram  25.0         IT  50000.0
# 2    sam   NaN    Finance  90000.0
# 3   gopi  24.0         IT  99000.0
# 4  vinay  30.0         HR      NaN

# %%
df.head()
# Out:
#     name  age department  salary
# 0   ajay   20         HR   65000
# 1    ram   25         IT   50000
# 2    sam   23    Finance   90000
# 3   gopi   24         IT   99000
# 4  vinay   30         HR   40000

# %%
df.tail(3)
# Out:
#     name  age department  salary
# 2    sam   23    Finance   90000
# 3   gopi   24         IT   99000
# 4  vinay   30         HR   40000

# %%
df.iloc[1:2]
# Out:
#   name  age department  salary
# 1  ram   25         IT   50000

# %%
df.loc[1:3,['age','department']]
# Out:
#    age department
# 1   25         IT
# 2   23    Finance
# 3   24         IT

# %%
df.drop('age',axis=1)
# Out:
#     name department   salary
# 0   ajay         HR  65000.0
# 1    ram         IT  50000.0
# 2    sam    Finance  90000.0
# 3   gopi         IT  99000.0
# 4  vinay         HR      NaN

# %%
df
# Out:
#     name   age department   salary
# 0   ajay  20.0         HR  65000.0
# 1    ram  25.0         IT  50000.0
# 2    sam   NaN    Finance  90000.0
# 3   gopi  24.0         IT  99000.0
# 4  vinay  30.0         HR      NaN

# %%
df.shape
# Out:
# (5, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        5 non-null      object
#  1   age         4 non-null      float64
#  2   department  5 non-null      object
#  3   salary      4 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 292.0+ bytes

# %%
df.describe()
# Out:
#              age        salary
# count   4.000000      4.000000
# mean   24.750000  76000.000000
# std     4.112988  22524.061209
# min    20.000000  50000.000000
# 25%    23.000000  61250.000000
# 50%    24.500000  77500.000000
# 75%    26.250000  92250.000000
# max    30.000000  99000.000000
